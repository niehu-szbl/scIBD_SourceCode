# %%
import os
import pandas as pd
import numpy as np
import scanpy as sc
from matplotlib.pyplot import rc_context
import matplotlib.pyplot as plt

# %%
import celltypist
from celltypist import models

# %%
## set working directory
os.chdir("/data1/niehu/ibd_public_data_20210821/analysis_20220111/02.integrate/T_NK/all_CD8_V2/")

# %%
adata0 = sc.read_h5ad("./all_CD8.n10.h5ad")

# %% [markdown]
# # resolution = 0.3

# %%
## read data
adata = sc.read_h5ad("./all_CD8.bySample.n10.bbknn_umap_leiden_marker.res0.3.h5ad")
adata.raw = adata0.raw.to_adata()
adata = sc.pp.subsample(adata, fraction=1., copy=True)

# %%
with rc_context({'figure.figsize': (4, 4)}):
    sc.pl.umap(adata, color=["study"])

# %%
with rc_context({'figure.figsize': (4, 4)}):
    sc.pl.umap(adata, color='leiden', legend_loc='on data', title='leiden', frameon=True, legend_fontsize = 8)

# %%
sc.pl.dotplot(adata, ["CD3D","CD3E","CD4","CD8A","CD8B",
                      "TRAC","TRBC2","TRDC","TRGC1","TRGC2","TRGV2","TRGV4","TRGV5","TRGV9",
                      "NKG7","GNLY","TYROBP","KLRD1", ## NK
                      "GZMB","FGFBP2","FCGR3A", ## NKT
                      "KIT",## ILC
                      "MKI67","TOP2A",
                       "HBA1","HBA2","HBB",
                      "FOXP3",
                     ], groupby='leiden')

# %%
predictions = celltypist.annotate(adata, model = 'Immune_All_Low.pkl', majority_voting = True, over_clustering = 'leiden')
# Out:
# 👀 Detected scaled expression in the input data, will try the `.raw` attribute
# 🔬 Input data has 187672 cells and 15813 genes
# 🔗 Matching reference genes in the model
# 🧬 1934 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!

# %%
adata = predictions.to_adata()

# %%
with rc_context({'figure.figsize': (4, 4)}):
    sc.pl.umap(adata, color = ['leiden', 'majority_voting'], legend_loc = 'on data')

# %% [markdown]
# # resolution = 0.6

# %%
## read data
adata = sc.read_h5ad("./all_CD8.bySample.n10.bbknn_umap_leiden_marker.res0.6.h5ad")
adata.raw = adata0.raw.to_adata()
adata = sc.pp.subsample(adata, fraction=1., copy=True)

# %%
with rc_context({'figure.figsize': (4, 4)}):
    sc.pl.umap(adata, color='leiden', legend_loc='on data', title='leiden', frameon=True, legend_fontsize = 8)

# %%
sc.pl.dotplot(adata, ["CD3D","CD3E","CD4","CD8A","CD8B",
                      "TRAC","TRBC2","TRDC","TRGC1","TRGC2","TRGV2","TRGV4","TRGV5","TRGV9",
                      "NKG7","GNLY","TYROBP","KLRD1", ## NK
                      "GZMB","FGFBP2","FCGR3A", ## NKT
                      "KIT",## ILC
                      "MKI67","TOP2A",
                       "HBA1","HBA2","HBB",
                      "FOXP3",
                     ], groupby='leiden')

# %%
predictions = celltypist.annotate(adata, model = 'Immune_All_Low.pkl', majority_voting = True, over_clustering = 'leiden')
# Out:
# 👀 Detected scaled expression in the input data, will try the `.raw` attribute
# 🔬 Input data has 187672 cells and 15813 genes
# 🔗 Matching reference genes in the model
# 🧬 1934 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!

# %%
adata = predictions.to_adata()

# %%
with rc_context({'figure.figsize': (4, 4)}):
    sc.pl.umap(adata, color = ['leiden', 'majority_voting'], legend_loc = 'on data')

# %% [markdown]
# # resolution = 0.9

# %%
## read data
adata = sc.read_h5ad("./all_CD8.bySample.n10.bbknn_umap_leiden_marker.res0.9.h5ad")
adata.raw = adata0.raw.to_adata()
adata = sc.pp.subsample(adata, fraction=1., copy=True)

# %%
with rc_context({'figure.figsize': (4, 4)}):
    sc.pl.umap(adata, color='leiden', legend_loc='on data', title='leiden', frameon=True, legend_fontsize = 8)

# %%
sc.pl.dotplot(adata, ["CD3D","CD3E","CD4","CD8A","CD8B",
                      "TRAC","TRBC2","TRDC","TRGC1","TRGC2","TRGV2","TRGV4","TRGV5","TRGV9",
                      "NKG7","GNLY","TYROBP","KLRD1", ## NK
                      "GZMB","FGFBP2","FCGR3A", ## NKT
                      "KIT",## ILC
                      "MKI67","TOP2A",
                       "HBA1","HBA2","HBB",
                      "FOXP3",
                     ], groupby='leiden')

# %% [markdown]
# # resolution = 1.2

# %%
## read data
adata = sc.read_h5ad("./all_CD8.bySample.n10.bbknn_umap_leiden_marker.res1.2.h5ad")
adata.raw = adata0.raw.to_adata()
adata = sc.pp.subsample(adata, fraction=1., copy=True)

# %%
with rc_context({'figure.figsize': (4, 4)}):
    sc.pl.umap(adata, color='leiden', legend_loc='on data', title='leiden', frameon=True, legend_fontsize = 8)

# %%
sc.pl.dotplot(adata, ["CD3D","CD3E","CD4","CD8A","CD8B",
                      "TRAC","TRBC2","TRDC","TRGC1","TRGC2","TRGV2","TRGV4","TRGV5","TRGV9",
                      "NKG7","GNLY","TYROBP","KLRD1", ## NK
                      "GZMB","FGFBP2","FCGR3A", ## NKT
                      "KIT",## ILC
                      "MKI67","TOP2A",
                       "HBA1","HBA2","HBB",
                      "FOXP3",
                      "CXCL13"
                     ], groupby='leiden')

# %%
predictions = celltypist.annotate(adata, model = 'Immune_All_Low.pkl', majority_voting = True, over_clustering = 'leiden')
# Out:
# 👀 Detected scaled expression in the input data, will try the `.raw` attribute
# 🔬 Input data has 187672 cells and 15813 genes
# 🔗 Matching reference genes in the model
# 🧬 1934 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!

# %%
adata = predictions.to_adata()

# %%
with rc_context({'figure.figsize': (4, 4)}):
    sc.pl.umap(adata, color = ['leiden', 'majority_voting'], legend_loc = 'on data')

# %% [markdown]
# # resolution = 1.5

# %%
## read data
adata = sc.read_h5ad("./all_CD8.bySample.n10.bbknn_umap_leiden_marker.res1.5.h5ad")
adata.raw = adata0.raw.to_adata()
adata = sc.pp.subsample(adata, fraction=1., copy=True)

# %%
with rc_context({'figure.figsize': (4, 4)}):
    sc.pl.umap(adata, color='leiden', legend_loc='on data', title='leiden', frameon=True, legend_fontsize = 8)

# %%
sc.pl.dotplot(adata, ["CD3D","CD3E","CD4","CD8A","CD8B",
                      "TRAC","TRBC2","TRDC","TRGC1","TRGC2","TRGV2","TRGV4","TRGV5","TRGV9",
                      "NKG7","GNLY","TYROBP","KLRD1", ## NK
                      "GZMB","FGFBP2","FCGR3A", ## NKT
                      "KIT",## ILC
                      "MKI67","TOP2A",
                       "HBA1","HBA2","HBB",
                      "FOXP3",
                     ], groupby='leiden')

# %%
sc.pl.dotplot(adata, ["CD3D","CD3E","CD4","CD8A","CD8B","CXCL13","PDCD1"], groupby='leiden')

# %%
with rc_context({'figure.figsize': (4, 4)}):
    sc.pl.umap(adata, color='leiden', legend_loc='on data', title='leiden', frameon=True, legend_fontsize = 8, groups = ['16'])

# %%
tmp = adata[adata.obs.leiden.isin(['16']),:]

# %%
tmp.obs.loc[CXCL13 > 0].study.value_counts()
# Out:
# MacroColonna_2021NC_cd_Tcell                           393
# AvivRegev_2019cell_uc                                   78
# John.T.Chang_2020SciImmunol_uc                          53
# MatthiasZilbauer_2021DevCell_cd                         51
# YuxiaZhang_Cell2019_ibd.discovery                       40
# EphraimKenigsberg_2019Cell_cd                           36
# YuxiaZhang_Cell2019_ibd.validation                      30
# AlisonSimmons_2020NatMed_uc_CD8Tcell                     7
# SarahA.Teichmann_Nature2021_intestinalDev_spacetime      2
# AlisonSimmons_2019Nature_uc_epithelial                   0
# Name: study, dtype: int64

# %%
CXCL13 = tmp[:,"CXCL13"].X.toarray()
PDCD1 = tmp[:,"PDCD1"].X.toarray()
CD8A = tmp[:,"CD8A"].X.toarray()

# %%
print( np.sum(np.logical_and(CXCL13 > 0, PDCD1 > 0)) )
print(len(CXCL13))
# Out:
# 290
# 3658

# %%
print(sum(CXCL13 > 0))
print(len(CXCL13))
# Out:
# [690]
# 3658

# %%
print( np.sum(np.logical_and(CXCL13 > 0, CD8A > 0)) )
print(len(CXCL13))
# Out:
# 198
# 3658

# %%
fig=plt.figure(figsize=(6,6))
plt.scatter(x=CD8A, y=CXCL13, alpha = 0.5, s = 0.5)
plt.xlabel("Relative expression of PDCD1")
plt.ylabel("Relative expression of CXCL13")
plt.savefig("test.png")

# %%
predictions = celltypist.annotate(adata, model = 'Immune_All_Low.pkl', majority_voting = True, over_clustering = 'leiden')
# Out:
# 👀 Detected scaled expression in the input data, will try the `.raw` attribute
# 🔬 Input data has 187672 cells and 15813 genes
# 🔗 Matching reference genes in the model
# 🧬 1934 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!

# %%
adata = predictions.to_adata()

# %%
with rc_context({'figure.figsize': (4, 4)}):
    sc.pl.umap(adata, color = ['leiden', 'majority_voting'], legend_loc = 'on data')

# %%
# done
